# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoperablack/HR_Analysis_Data/blob/main/HR_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import seaborn as sns

# %%
HR_Data = pd.read_csv('/content/drive/MyDrive/DataSet/HRDataset_v14.csv')
HR_Data
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0              1       5            4                       0   62506  ...
# 1              5       3            3                       0  104437  ...
# 2              5       5            3                       0   64955  ...
# 3              1       5            3                       0   64991  ...
# 4              5       5            3                       0   50825  ...
# ..           ...     ...          ...                     ...     ...  ...
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#         ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# 0    Michael Albert       22.0           LinkedIn          Exceeds
# 1        Simon Roup        4.0             Indeed      Fully Meets
# 2    Kissy Sullivan       20.0           LinkedIn      Fully Meets
# 3      Elijiah Gray       16.0             Indeed      Fully Meets
# 4    Webster Butler       39.0      Google Search      Fully Meets
# ..              ...        ...                ...              ...
# 306  Kissy Sullivan       20.0           LinkedIn      Fully Meets
# 307  Brannon Miller       12.0      Google Search              PIP
# 308      Janet King        2.0  Employee Referral          Exceeds
# 309      Simon Roup        4.0  Employee Referral      Fully Meets
# 310   David Stanley       14.0           LinkedIn      Fully Meets
#
#      EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0                4.60               5                    0
# 1                4.96               3                    6
# 2                3.02               3                    0
# 3                4.84               5                    0
# 4                5.00               4                    0
# ..                ...             ...                  ...
# 306              4.07               4                    0
# 307              3.20               2                    0
# 308              4.60               5                    6
# 309              5.00               3                    5
# 310              4.50               5                    0
#
#     LastPerformanceReview_Date DaysLateLast30 Absences
# 0                    1/17/2019              0        1
# 1                    2/24/2016              0       17
# 2                    5/15/2012              0        3
# 3                     1/3/2019              0       15
# 4                     2/1/2016              0        2
# ..                         ...            ...      ...
# 306                  2/28/2019              0       13
# 307                   9/2/2015              5        4
# 308                  2/21/2019              0       16
# 309                   2/1/2019              0       11
# 310                  1/30/2019              0        2
#
# [311 rows x 36 columns]

# %%
HR_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
#  13  State                       311 non-null    object
#  14  Zip                         311 non-null    int64
#  15  DOB                         311 non-null    object
#  16  Sex                         311 non-null    object
#  17  MaritalDesc                 311 non-null    object
#  18  CitizenDesc                 311 non-null    object
#  19  HispanicLatino              311 non-null    object
#  20  RaceDesc                    311 non-null    object
#  21  DateofHire                  311 non-null    object
#  22  DateofTermination           104 non-null    object
#  23  TermReason                  311 non-null    object
#  24  EmploymentStatus            311 non-null    object
#  25  Department                  311 non-null    object
#  26  ManagerName                 311 non-null    object
#  27  ManagerID                   303 non-null    float64
#  28  RecruitmentSource           311 non-null    object
#  29  PerformanceScore            311 non-null    object
#  30  EngagementSurvey            311 non-null    float64
#  31  EmpSatisfaction             311 non-null    int64
#  32  SpecialProjectsCount        311 non-null    int64
#  33  LastPerformanceReview_Date  311 non-null    object
#  34  DaysLateLast30              311 non-null    int64
#  35  Absences                    311 non-null    int64
# dtypes: float64(2), int64(16), object(18)
# memory usage: 87.6+ KB

# %% [markdown]
# ### How would you calculate the median salary for employees who are still actively employed?

# %%
Status = HR_Data['EmploymentStatus']
Status
# Out:
# 0                      Active
# 1      Voluntarily Terminated
# 2      Voluntarily Terminated
# 3                      Active
# 4      Voluntarily Terminated
#                 ...
# 306                    Active
# 307    Voluntarily Terminated
# 308                    Active
# 309                    Active
# 310                    Active
# Name: EmploymentStatus, Length: 311, dtype: object

# %%
HR_Data['EmploymentStatus'] = HR_Data['EmploymentStatus'].replace(' ', '_', regex=True)
HR_Data['EmploymentStatus']
# Out:
# 0                      Active
# 1      Voluntarily_Terminated
# 2      Voluntarily_Terminated
# 3                      Active
# 4      Voluntarily_Terminated
#                 ...
# 306                    Active
# 307    Voluntarily_Terminated
# 308                    Active
# 309                    Active
# 310                    Active
# Name: EmploymentStatus, Length: 311, dtype: object

# %%
active_employees = HR_Data[HR_Data['EmploymentStatus'] == 'Active']
active_employees
# Out:
#            Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi, Wilson  K  10026          0                0         1
# 3           Alagbe,Trina  10088          1                1         0
# 5      Anderson, Linda    10002          0                0         0
# 6        Andreola, Colby  10194          0                0         0
# 7            Athwal, Sam  10062          0                4         1
# ..                   ...    ...        ...              ...       ...
# 305        Wolk, Hang  T  10174          0                0         0
# 306       Woodson, Jason  10135          0                0         1
# 308     Zamora, Jennifer  10010          0                0         0
# 309          Zhou, Julia  10043          0                0         0
# 310        Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0              1       5            4                       0   62506  ...
# 3              1       5            3                       0   64991  ...
# 5              1       5            4                       0   57568  ...
# 6              1       4            3                       0   95660  ...
# 7              1       5            3                       0   59365  ...
# ..           ...     ...          ...                     ...     ...  ...
# 305            1       5            3                       0   60446  ...
# 306            1       5            3                       0   65893  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#          ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# 0     Michael Albert       22.0           LinkedIn          Exceeds
# 3       Elijiah Gray       16.0             Indeed      Fully Meets
# 5           Amy Dunn       11.0           LinkedIn          Exceeds
# 6    Alex Sweetwater       10.0           LinkedIn      Fully Meets
# 7      Ketsia Liebig       19.0  Employee Referral      Fully Meets
# ..               ...        ...                ...              ...
# 305    David Stanley       14.0           LinkedIn      Fully Meets
# 306   Kissy Sullivan       20.0           LinkedIn      Fully Meets
# 308       Janet King        2.0  Employee Referral          Exceeds
# 309       Simon Roup        4.0  Employee Referral      Fully Meets
# 310    David Stanley       14.0           LinkedIn      Fully Meets
#
#      EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0                4.60               5                    0
# 3                4.84               5                    0
# 5                5.00               5                    0
# 6                3.04               3                    4
# 7                5.00               4                    0
# ..                ...             ...                  ...
# 305              3.40               4                    0
# 306              4.07               4                    0
# 308              4.60               5                    6
# 309              5.00               3                    5
# 310              4.50               5                    0
#
#     LastPerformanceReview_Date DaysLateLast30 Absences
# 0                    1/17/2019              0        1
# 3                     1/3/2019              0       15
# 5                     1/7/2019              0       15
# 6                     1/2/2019              0       19
# 7                    2/25/2019              0       19
# ..                         ...            ...      ...
# 305                  2/21/2019              0       14
# 306                  2/28/2019              0       13
# 308                  2/21/2019              0       16
# 309                   2/1/2019              0       11
# 310                  1/30/2019              0        2
#
# [207 rows x 36 columns]

# %%
median_salary = active_employees['Salary'].median()
median_salary
# Out:
# 63051.0

# %% [markdown]
# ### How can you filter the DataFrame to show employees who have been terminated and had a performance score of "Exceeds"?

# %%
terminated_exceeds = HR_Data[(HR_Data['EmploymentStatus'] == 'Voluntarily_Terminated') & (HR_Data['PerformanceScore'] == 'Exceeds')]
terminated_exceeds
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 143     Johnson, George  10034          1                1         1
# 174      Lynch, Lindsay  10004          0                0         0
# 212    Patronick, Lucas  10005          0                0         1
# 217      Peters, Lauren  10032          1                1         0
# 265  Squatrito, Kristen  10030          0                2         0
# 289    Veera, Abdellah   10014          0                2         1
# 304  Winthrop, Jordan    10033          0                0         1
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 143            5       5            4                       0   46837  ...
# 174            5       5            4                       1   47434  ...
# 212            5       4            4                       1  108987  ...
# 217            5       5            4                       0   57954  ...
# 265            5       5            4                       0   62425  ...
# 289            5       5            4                       0   58523  ...
# 304            5       5            4                       0   70507  ...
#
#          ManagerName  ManagerID   RecruitmentSource PerformanceScore  \
# 143   Michael Albert       22.0       CareerBuilder          Exceeds
# 174   Webster Butler       39.0  Diversity Job Fair          Exceeds
# 212  Alex Sweetwater       10.0  Diversity Job Fair          Exceeds
# 217    Ketsia Liebig       19.0              Indeed          Exceeds
# 265    David Stanley       14.0            LinkedIn          Exceeds
# 289   Kissy Sullivan       20.0            LinkedIn          Exceeds
# 304   Brannon Miller       12.0            LinkedIn          Exceeds
#
#      EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 143               4.7               4                    0
# 174               5.0               4                    0
# 212               5.0               5                    3
# 217               4.2               5                    0
# 265               4.1               4                    0
# 289               4.5               5                    0
# 304               5.0               3                    0
#
#     LastPerformanceReview_Date DaysLateLast30 Absences
# 143                  2/14/2018              0        9
# 174                   2/2/2015              0       17
# 212                  8/16/2015              0       13
# 217                  1/10/2013              0       12
# 265                   3/2/2015              0       16
# 289                   2/1/2016              0       15
# 304                  1/19/2016              0        7
#
# [7 rows x 36 columns]

# %% [markdown]
# ### How would you group the data by Department and GenderID to calculate the average engagement survey score for each combination?

# %%
grouped_data = HR_Data.groupby(['Department', 'GenderID'])['EngagementSurvey'].mean().reset_index()
grouped_data
# Out:
#               Department  GenderID  EngagementSurvey
# 0          Admin Offices         0          4.423333
# 1          Admin Offices         1          4.333333
# 2       Executive Office         0          4.830000
# 3                  IT/IS         0          4.287273
# 4                  IT/IS         1          4.049286
# 5      Production                0          4.111984
# 6      Production                1          4.156265
# 7                  Sales         0          4.092000
# 8                  Sales         1          3.562500
# 9   Software Engineering         0          3.765000
# 10  Software Engineering         1          4.418000

# %%
terminated_employees = HR_Data[HR_Data['EmploymentStatus'] == 'Voluntarily_Terminated']
terminated_employees
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# 10       Baczenski, Rachael    10252          1                1         0
# 11            Barbara, Thomas  10242          1                1         1
# ..                        ...    ...        ...              ...       ...
# 301             Wilber, Barry  10048          1                1         1
# 302             Wilkes, Annie  10204          0                2         0
# 303     Williams, Jacquelyn    10264          0                0         0
# 304        Winthrop, Jordan    10033          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 1              5       3            3                       0  104437  ...
# 2              5       5            3                       0   64955  ...
# 4              5       5            3                       0   50825  ...
# 10             5       5            3                       1   54670  ...
# 11             5       5            3                       1   47211  ...
# ..           ...     ...          ...                     ...     ...  ...
# 301            5       5            3                       0   55140  ...
# 302            5       5            3                       0   58062  ...
# 303            5       5            3                       1   59728  ...
# 304            5       5            4                       0   70507  ...
# 307            5       5            1                       0   48513  ...
#
#         ManagerName  ManagerID   RecruitmentSource PerformanceScore  \
# 1        Simon Roup        4.0              Indeed      Fully Meets
# 2    Kissy Sullivan       20.0            LinkedIn      Fully Meets
# 4    Webster Butler       39.0       Google Search      Fully Meets
# 10    David Stanley       14.0  Diversity Job Fair      Fully Meets
# 11   Kissy Sullivan       20.0  Diversity Job Fair      Fully Meets
# ..              ...        ...                 ...              ...
# 301        Amy Dunn       11.0             Website      Fully Meets
# 302   Ketsia Liebig       19.0       Google Search      Fully Meets
# 303   Ketsia Liebig       19.0  Diversity Job Fair      Fully Meets
# 304  Brannon Miller       12.0            LinkedIn          Exceeds
# 307  Brannon Miller       12.0       Google Search              PIP
#
#      EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 1                4.96               3                    6
# 2                3.02               3                    0
# 4                5.00               4                    0
# 10               4.20               4                    0
# 11               4.20               3                    0
# ..                ...             ...                  ...
# 301              5.00               3                    0
# 302              3.60               5                    0
# 303              4.30               4                    0
# 304              5.00               3                    0
# 307              3.20               2                    0
#
#     LastPerformanceReview_Date DaysLateLast30 Absences
# 1                    2/24/2016              0       17
# 2                    5/15/2012              0        3
# 4                     2/1/2016              0        2
# 10                   1/30/2016              0       12
# 11                    5/6/2016              0       15
# ..                         ...            ...      ...
# 301                  2/15/2015              0        7
# 302                   2/6/2011              0        9
# 303                   6/2/2014              0       16
# 304                  1/19/2016              0        7
# 307                   9/2/2015              5        4
#
# [88 rows x 36 columns]

# %% [markdown]
# ### How can you find the most common recruitment source for terminated employees?

# %%
most_common_source = terminated_employees['RecruitmentSource'].mode()[0]
most_common_source
# Out:
# 'Google Search'

# %% [markdown]
# ###  How would you sort the DataFrame by the number of absences, and then by the number of days late in the last 30 days, both in descending order?

# %%
HR_Data_sorted = HR_Data.sort_values(by=['Absences', 'DaysLateLast30'], ascending=[False, False])
HR_Data_sorted
# Out:
#                Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 263         Sparks, Taylor    10302          1                1         0
# 15             Bates, Norman  10061          0                0         1
# 93   Fitzpatrick, Michael  J  10093          0                0         1
# 107           Givens, Myriam  10255          0                0         0
# 109              Goeth, Amon  10228          1                1         1
# ..                       ...    ...        ...              ...       ...
# 145            Johnston, Yen  10036          0                0         0
# 191          Monterro, Luisa  10025          0                0         0
# 207           Onque, Jasmine  10121          0                0         0
# 274            Szabo, Andrew  10024          0                0         1
# 279       Theamstern, Sophia  10141          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 263            1       5            1                       0   64021  ...
# 15             4       5            3                       0   57834  ...
# 93             5       5            3                       0   72609  ...
# 107            1       6            3                       0   61555  ...
# 109            1       3            3                       0   74679  ...
# ..           ...     ...          ...                     ...     ...  ...
# 145            1       5            4                       0   63322  ...
# 191            1       5            4                       0   72460  ...
# 207            1       6            3                       0   63051  ...
# 274            1       4            4                       0   92989  ...
# 279            5       5            3                       0   48413  ...
#
#      EmpSatisfaction  SpecialProjectsCount LastPerformanceReview_Date  \
# 263                2                     1                  2/25/2019
# 15                 4                     0                   4/5/2017
# 93                 5                     0                   4/5/2013
# 107                5                     0                  1/25/2019
# 109                5                     7                  1/10/2019
# ..               ...                   ...                        ...
# 145                3                     0                  1/11/2019
# 191                3                     0                  1/14/2019
# 207                3                     0                  1/25/2019
# 274                5                     5                  2/18/2019
# 279                4                     0                   3/2/2016
#
#     DaysLateLast30  Absences        DOT LengthOfEmp YearOfBirth Age    Tenure
# 263              6        20 2024-08-30        4575        1968  56       NaN
# 15               0        20 2017-08-04        2356        1981  43  6.450376
# 93               0        20 2013-06-24         770        1981  43  2.108145
# 107              0        20 2024-08-30        3483        1989  35       NaN
# 109              0        20 2024-08-30        3441        1989  35       NaN
# ..             ...       ...        ...         ...         ...  ..       ...
# 145              0         1 2024-08-30        3707        1969  55       NaN
# 191              0         1 2024-08-30        4127        1970  54       NaN
# 207              0         1 2024-08-30        3987        1990  34       NaN
# 274              0         1 2024-08-30        3707        1983  41       NaN
# 279              0         1 2016-09-05        1889        1965  59  5.171800
#
# [311 rows x 41 columns]

# %% [markdown]
# ###  How can you identify and drop any rows where the PerformanceScore is missing, and then calculate the average performance score for the remaining data?

# %%
HR_Data_cleaned = HR_Data.dropna(subset=['PerformanceScore'])
HR_Data_cleaned
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0              1       5            4                       0   62506  ...
# 1              5       3            3                       0  104437  ...
# 2              5       5            3                       0   64955  ...
# 3              1       5            3                       0   64991  ...
# 4              5       5            3                       0   50825  ...
# ..           ...     ...          ...                     ...     ...  ...
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#      EmpSatisfaction  SpecialProjectsCount LastPerformanceReview_Date  \
# 0                  5                     0                  1/17/2019
# 1                  3                     6                  2/24/2016
# 2                  3                     0                  5/15/2012
# 3                  5                     0                   1/3/2019
# 4                  4                     0                   2/1/2016
# ..               ...                   ...                        ...
# 306                4                     0                  2/28/2019
# 307                2                     0                   9/2/2015
# 308                5                     6                  2/21/2019
# 309                3                     5                   2/1/2019
# 310                5                     0                  1/30/2019
#
#     DaysLateLast30  Absences        DOT LengthOfEmp YearOfBirth Age    Tenure
# 0                0         1 2024-08-30        4805        1983  41       NaN
# 1                0        17 2016-06-16         444        1975  49  1.215606
# 2                0         3 2012-09-24         447        1988  36  1.223819
# 3                0        15 2024-08-30        6080        1988  36       NaN
# 4                0         2 2016-09-06        1884        1989  35  5.158111
# ..             ...       ...        ...         ...         ...  ..       ...
# 306              0        13 2024-08-30        3707        1985  39       NaN
# 307              5         4 2015-09-29        2583        1982  42  7.071869
# 308              0        16 2024-08-30        5256        1979  45       NaN
# 309              0        11 2024-08-30        3441        1979  45       NaN
# 310              0         2 2024-08-30        3623        1978  46       NaN
#
# [311 rows x 41 columns]

# %%
average_performance_score = HR_Data_cleaned['PerformanceScore'].mode()
average_performance_score
# Out:
# 0    Fully Meets
# Name: PerformanceScore, dtype: object

# %%
HR_Data_cleaned['PerformanceScore'].value_counts()
# Out:
# PerformanceScore
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13
# Name: count, dtype: int64

# %% [markdown]
# ### How would you create a new column that calculates each employee's tenure in years and then find the average tenure for each department?

# %%
HR_Data['DateofTermination'] = pd.to_datetime(HR_Data['DateofTermination'])
HR_Data['DateofHire'] = pd.to_datetime(HR_Data['DateofHire'])

# %%
HR_Data['Tenure'] = (HR_Data['DateofTermination'] - HR_Data['DateofHire']).dt.days / 365.25
HR_Data
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0              1       5            4                       0   62506  ...
# 1              5       3            3                       0  104437  ...
# 2              5       5            3                       0   64955  ...
# 3              1       5            3                       0   64991  ...
# 4              5       5            3                       0   50825  ...
# ..           ...     ...          ...                     ...     ...  ...
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#      EmpSatisfaction  SpecialProjectsCount LastPerformanceReview_Date  \
# 0                  5                     0                  1/17/2019
# 1                  3                     6                  2/24/2016
# 2                  3                     0                  5/15/2012
# 3                  5                     0                   1/3/2019
# 4                  4                     0                   2/1/2016
# ..               ...                   ...                        ...
# 306                4                     0                  2/28/2019
# 307                2                     0                   9/2/2015
# 308                5                     6                  2/21/2019
# 309                3                     5                   2/1/2019
# 310                5                     0                  1/30/2019
#
#     DaysLateLast30  Absences        DOT LengthOfEmp YearOfBirth Age    Tenure
# 0                0         1 2024-08-30        4805        1983  41       NaN
# 1                0        17 2016-06-16         444        1975  49  1.215606
# 2                0         3 2012-09-24         447        1988  36  1.223819
# 3                0        15 2024-08-30        6080        1988  36       NaN
# 4                0         2 2016-09-06        1884        1989  35  5.158111
# ..             ...       ...        ...         ...         ...  ..       ...
# 306              0        13 2024-08-30        3707        1985  39       NaN
# 307              5         4 2015-09-29        2583        1982  42  7.071869
# 308              0        16 2024-08-30        5256        1979  45       NaN
# 309              0        11 2024-08-30        3441        1979  45       NaN
# 310              0         2 2024-08-30        3623        1978  46       NaN
#
# [311 rows x 41 columns]

# %%
average_tenure_by_department = HR_Data.groupby('Department')['Tenure'].mean().reset_index()
average_tenure_by_department
# Out:
#              Department    Tenure
# 0         Admin Offices  1.078713
# 1      Executive Office       NaN
# 2                 IT/IS  1.749760
# 3     Production         3.754385
# 4                 Sales  2.625599
# 5  Software Engineering  3.889802

# %% [markdown]
# ###  How can you find the top 5 employees with the highest special projects count who have also been terminated for cause, and display their relevant details?

# %%
term_grouped_data = HR_Data.groupby(['TermReason', 'Employee_Name', 'Department','Salary','Sex'])['SpecialProjectsCount'].mean()
term_grouped_data.sort_values(ascending=False).head(5)

# %% [markdown]
# ### What is the distribution of employee salaries?

# %%
sns.displot(HR_Data['Salary'], color='Red')
plt.title('Employee Salary Distribution')
plt.xlabel('Salary',color='blue')
plt.ylabel('Frequency',color='Orange')
# Out:
# Text(13.819444444444445, 0.5, 'Frequency')

# %% [markdown]
# ### How does employee satisfaction vary across different departments?

# %%
avg_satisfaction = HR_Data.groupby('Department')['EmpSatisfaction'].mean().reset_index()
avg_satisfaction.sort_values(by='EmpSatisfaction', ascending=False)
# Out:
#              Department  EmpSatisfaction
# 5  Software Engineering         4.090909
# 4                 Sales         4.032258
# 2                 IT/IS         3.960000
# 3     Production                3.861244
# 0         Admin Offices         3.555556
# 1      Executive Office         3.000000

# %%
ax = sns.barplot(data=HR_Data,
                 x='Department',
                 y='EmpSatisfaction',
                 errorbar=None)

plt.title('Employee Satisfaction across departments')
plt.xticks(rotation=35)
plt.xlabel('')
plt.show()

# %% [markdown]
# ###  What is the gender distribution across various job positions?

# %%
ax = sns.countplot(x="Department", hue="Sex", data= HR_Data)

plt.title('Gender distribution across departments')
plt.xticks(rotation=35)
plt.xlabel('')
plt.show()

# %% [markdown]
# ###Is there a relationship between tenure (length of employment) and salary?

# %%
HR_Data['DOT'] = HR_Data['DateofTermination'].copy()
curr_date = pd.to_datetime('today').date()
HR_Data['DOT'] = HR_Data['DOT'].fillna(curr_date)
HR_Data['DOT']
# Out:
# 0      2024-08-30
# 1       6/16/2016
# 2       9/24/2012
# 3      2024-08-30
# 4        9/6/2016
#           ...
# 306    2024-08-30
# 307     9/29/2015
# 308    2024-08-30
# 309    2024-08-30
# 310    2024-08-30
# Name: DOT, Length: 311, dtype: object

# %%
HR_Data['DateofHire'] = pd.to_datetime(HR_Data['DateofHire'])
HR_Data['DOT'] = pd.to_datetime(HR_Data['DOT'])
HR_Data['LengthOfEmp'] = HR_Data['DOT'] - HR_Data['DateofHire']
HR_Data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    RecruitmentSource  PerformanceScore EngagementSurvey EmpSatisfaction  \
# 0           LinkedIn           Exceeds             4.60               5
# 1             Indeed       Fully Meets             4.96               3
# 2           LinkedIn       Fully Meets             3.02               3
# 3             Indeed       Fully Meets             4.84               5
# 4      Google Search       Fully Meets             5.00               4
#
#    SpecialProjectsCount LastPerformanceReview_Date DaysLateLast30 Absences  \
# 0                     0                  1/17/2019              0        1
# 1                     6                  2/24/2016              0       17
# 2                     0                  5/15/2012              0        3
# 3                     0                   1/3/2019              0       15
# 4                     0                   2/1/2016              0        2
#
#          DOT LengthOfEmp
# 0 2024-08-30   4805 days
# 1 2016-06-16    444 days
# 2 2012-09-24    447 days
# 3 2024-08-30   6080 days
# 4 2016-09-06   1884 days
#
# [5 rows x 38 columns]

# %%
HR_Data['LengthOfEmp'] = HR_Data['LengthOfEmp'].astype(str)
HR_Data['LengthOfEmp'] = HR_Data['LengthOfEmp'].str.replace(' days', '')
HR_Data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    RecruitmentSource  PerformanceScore EngagementSurvey EmpSatisfaction  \
# 0           LinkedIn           Exceeds             4.60               5
# 1             Indeed       Fully Meets             4.96               3
# 2           LinkedIn       Fully Meets             3.02               3
# 3             Indeed       Fully Meets             4.84               5
# 4      Google Search       Fully Meets             5.00               4
#
#    SpecialProjectsCount LastPerformanceReview_Date DaysLateLast30 Absences  \
# 0                     0                  1/17/2019              0        1
# 1                     6                  2/24/2016              0       17
# 2                     0                  5/15/2012              0        3
# 3                     0                   1/3/2019              0       15
# 4                     0                   2/1/2016              0        2
#
#          DOT LengthOfEmp
# 0 2024-08-30        4805
# 1 2016-06-16         444
# 2 2012-09-24         447
# 3 2024-08-30        6080
# 4 2016-09-06        1884
#
# [5 rows x 38 columns]

# %%
ax = sns.scatterplot(data=HR_Data,
                     x='Salary',
                     y='LengthOfEmp')

#hide y-axis
ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ###What is the distribution of employees across different recruitment sources?

# %%
ax = sns.barplot(data=HR_Data,
                 x='RecruitmentSource',
                 y='EmpID',
                 estimator='count',
                 errorbar=None)

plt.title('Distribution of employees across different recruitment sources')
plt.xticks(rotation=35)
plt.xlabel('')
plt.show()

# %% [markdown]
# ###How does employee absenteeism vary by department?

# %%
ax = sns.barplot(data=HR_Data,
                 x='Department',
                 y='Absences',
                 estimator='mean',
                 errorbar=None)

plt.title('Employee absenteeism vary by department')
plt.xticks(rotation=35)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### What is the average age of employees in different job roles or departments?

# %%
HR_Data['DOB'] = pd.to_datetime(HR_Data.DOB, format="%m/%d/%y")
HR_Data['YearOfBirth'] = HR_Data['DOB'].dt.year
curr_year = pd.to_datetime('today').date().year

# Manually adjust the year to be in the 1900s if necessary
def adjust_date(x):
    if x > curr_year:
        return x - 100
    else:
        return x

HR_Data['YearOfBirth'] = HR_Data['YearOfBirth'].apply(adjust_date)

HR_Data['Age'] = curr_year - HR_Data['YearOfBirth']

HR_Data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    EngagementSurvey  EmpSatisfaction SpecialProjectsCount  \
# 0              4.60                5                    0
# 1              4.96                3                    6
# 2              3.02                3                    0
# 3              4.84                5                    0
# 4              5.00                4                    0
#
#   LastPerformanceReview_Date  DaysLateLast30 Absences        DOT LengthOfEmp  \
# 0                  1/17/2019               0        1 2024-08-30        4805
# 1                  2/24/2016               0       17 2016-06-16         444
# 2                  5/15/2012               0        3 2012-09-24         447
# 3                   1/3/2019               0       15 2024-08-30        6080
# 4                   2/1/2016               0        2 2016-09-06        1884
#
#   YearOfBirth Age
# 0        1983  41
# 1        1975  49
# 2        1988  36
# 3        1988  36
# 4        1989  35
#
# [5 rows x 40 columns]

# %%
ax = sns.barplot(data=HR_Data,
                 x='Department',
                 y='Age',
                 estimator='mean',
                 errorbar=None)

plt.title('Average age of employees in different departments')
plt.xticks(rotation=35)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### How does employee turnover (termination) vary by department?

# %%
churned_emps = HR_Data[HR_Data['DateofTermination'].notnull()]

ax = sns.barplot(data=churned_emps,
                 x='Department',
                 y='EmpID',
                 estimator='count',
                 errorbar=None)

plt.title('Employee turnover by department')
plt.xticks(rotation=35)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### What is the distribution of special projects count among employees

# %%
ax = sns.barplot(data=HR_Data,
                 x='Department',
                 y='SpecialProjectsCount',
                 estimator='sum',
                 errorbar=None)

plt.title('Distribution of special projects count across departments')
plt.xticks(rotation=35)
plt.xlabel('')
plt.show()
